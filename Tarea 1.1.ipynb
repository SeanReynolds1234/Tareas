# %% [markdown]
# ## Tarea 1.1

# %% [markdown]
# Modifique el siguiente código para que no saque error

# %%
def fun(n):
    return 1/n

print(fun(0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-065e8f55d9cc> in <module>
#       2     return 1/n
#       3
# ----> 4 print(fun(0))
#
# <ipython-input-1-065e8f55d9cc> in fun(n)
#       1 def fun(n):
# ----> 2     return 1/n
#       3
#       4 print(fun(0))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **Solución 1:** Se puede simplemente cambiar el valor que se busca. En vez de 0 usar otro valor, como el valor 2, por ejemplo.

# %%
#Se define una función cualquiera
def fun(n):
    return 1/n #Le pides que te entregue un cálculo

#Le das un valor a la función para que se evalúe sin entregar un error
print(fun(2))
# Out:
# 0.5

# %% [markdown]
# **Solución 2:** Generar un código que entregue un mensaje, esto impide obtener un error.

# %%
#Se define una función cualquiera
def fun(n):
    
    #Primero se define lo que sucede cuando se intenta evaluar por un valor el cual la función no permite
    if n == 0:
        return('No se puede dividir por cero') #Se genera un mensaje advirtiendo
    
    #Luego se define lo que sucede si se intenta evaluar por un valor que la función sí permite
    else:
        return 1/n

#Finalmente se puede evaluar el valor que se quiera asignar sin dar error
print(fun(0))
# Out:
# No se puede dividir por cero
